# %% [markdown]
# * Exercises: Level 1
# 1. Inside 30DaysOfPython create a folder called day_2. Inside this folder create a file named variables.py
# 2. Write a python comment saying 'Day 2: 30 Days of python programming'
# 3. Declare a first name variable and assign a value to it
# 4. Declare a last name variable and assign a value to it
# 5. Declare a full name variable and assign a value to it
# 6. Declare a country variable and assign a value to it
# 7. Declare a city variable and assign a value to it
# 8. Declare an age variable and assign a value to it
# 9. Declare a year variable and assign a value to it
# 10. Declare a variable is_married and assign a value to it
# 11. Declare a variable is_true and assign a value to it
# 12. Declare a variable is_light_on and assign a value to it
# 13. Declare multiple variable on one line

# %%
#2
# Day 2
#3
first_name="7sh"

#4
last_name="k"

#5
full_name="7sh_k"

#complete
country, city, age, year, is_married, is_true, is_light_on = "IND", "DND", 11, 2006, True, False, True

# %%
print(country)
print(full_name)
# Out:
# IND
# 7sh_k

# %% [markdown]
# ### Exercises: Level 2
# - Check the data type of all your variables using type() built-in function
# - Using the len() built-in function, find the length of your first name
# - Compare the length of your first name and your last name
# - Declare 5 as num_one and 4 as num_two
# - Add num_one and num_two and assign the value to a variable total
# - Subtract num_two from num_one and assign the value to a variable diff
# - Multiply num_two and num_one and assign the value to a variable product
# - Divide num_one by num_two and assign the value to a variable division
# - Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
# - Calculate num_one to the power of num_two and assign the value to a variable exp
# - Find floor division of num_one by num_two and assign the value to a variable floor_division
# - The radius of a circle is 30 meters.
# - Calculate the area of a circle and assign the value to a variable name of area_of_circle
# - Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
# - Take radius as user input and calculate the area.
# - Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names
# - Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords

# %%
print(type(full_name))

print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print("Lenght of first name: ", len(first_name))

print("lenght of last name : ", len(last_name))
# Out:
# Lenght of first name:  3
# lenght of last name :  1

# %%
num_1= 5
num_2= 4

total= num_1 + num_2

diff= num_2 - num_1

prod = num_2 * num_1

div= num_1 / num_2

remainder= num_1/ num_2

# %%
exp , floor_division = num_1 ** num_2, num_1 // num_2

# %%
radius =30

area= (22/7) * radius**2

circum_of_circle= 2* (22/7)* radius

# %%
r= int(input("Enter raduis"))
area= 3.14* r * r
print(area)
# Out:
# 153.86

# %%
data = []

for _ in range(4):
    value = input("Enter first name, last name, country, age (one by one): ")
    data.append(value)

print(data)
# Out:
# ['Alex', 'ander', 'Rome', '34']
